# %%
import pandas as pd

# %%
dataframe = pd.read_excel(r'C:\Users\mariu\Documents\Project Local Elections\bayern_historisch_search.xlsx')

# %%
dataframe_1 = dataframe.drop(['Unnamed: 10', 'Unnamed: 11'], axis = 1)
search = dataframe_1['search'].str.split(' ', expand = True)

search_2 = search.drop([0, 1, 2, 3, 5], axis = 1)
dataframe_2 = pd.concat([dataframe_1, search], ignore_index=1, axis=1)
dataframe_3 = dataframe_2.drop([10, 11, 12, 13, 14, 16], axis=1)

dataframe_3.columns = ['city', 'year', 'party', 'place_list', 'name_official', 'votes', 'doctor', 'last_name', 'first_name',
                        'name_complet', 'search_result']

dataframe_3.search_result = dataframe_3.search_result.str.replace(',', '')
dataframe_3['search_result'] = dataframe_3['search_result'].astype(float).fillna(0.0).astype(int)

dataframe_3.head()

# %%
dataframe_3['last_letter'] = dataframe_3.first_name.str[-1]
dataframe_3['pre_last_letter'] = dataframe_3.first_name.str[-2]
dataframe_3['third_last_letter'] = dataframe_3.first_name.str[-3]
dataframe_3['fourth_last_letter'] = dataframe_3.first_name.str[-4]
dataframe_3['fifth_last_letter'] = dataframe_3.first_name.str[-5]
dataframe_3['sixth_last_letter'] = dataframe_3.first_name.str[-6]
dataframe_3['seventh_last_letter'] = dataframe_3.first_name.str[-7]
dataframe_3['eigth_last_letter'] = dataframe_3.first_name.str[-8]
dataframe_3.head()

# %%
dataframe_3.loc[dataframe_3['last_letter'] == 'a', 'Male'] = 0
dataframe_3.loc[dataframe_3['last_letter'] == 'e', 'Male'] = 0
dataframe_3.loc[dataframe_3['last_letter'] == 'o', 'Male'] = 1

dataframe_3.loc[(dataframe_3['last_letter'] != 'a') & (dataframe_3['last_letter'] != 'e') & (dataframe_3['last_letter'] != 'd') & (dataframe_3['last_letter'] != 't'), 'Male'] = 1

dataframe_3.loc[(dataframe_3['last_letter'] == 'h') & (dataframe_3['pre_last_letter'] == 't'), 'Male' ] = 0

dataframe_3.loc[(dataframe_3['last_letter'] == 'x') & (dataframe_3['third_last_letter'] == 'r'), 'Male' ] = 0

dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'l') & (dataframe_3['third_last_letter'] == 'o'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'l') & (dataframe_3['third_last_letter'] == 'i'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'l') & (dataframe_3['third_last_letter'] == 'a'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'r') & (dataframe_3['third_last_letter'] == 'a'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'r') & (dataframe_3['third_last_letter'] == 'a') & (dataframe_3['fourth_last_letter'] == 'g'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'n'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'e'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'a'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'i'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'u'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'd') & (dataframe_3['pre_last_letter'] == 'r') & (dataframe_3['third_last_letter'] == 'e'), 'Male' ] = 1

dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'r'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'u'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'h'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 's'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'e'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'a'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'd'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'k'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'n'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'i'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 't'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 't') & (dataframe_3['pre_last_letter'] == 'o'), 'Male' ] = 0

dataframe_3.loc[(dataframe_3['last_letter'] == 'n') & (dataframe_3['pre_last_letter'] == 'i') & (dataframe_3['third_last_letter'] == 'r'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'n') & (dataframe_3['pre_last_letter'] == 'u') & (dataframe_3['third_last_letter'] == 'r'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'n') & (dataframe_3['pre_last_letter'] == 'e') & (dataframe_3['third_last_letter'] == 't') & (dataframe_3['fourth_last_letter'] == 's'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'n') & (dataframe_3['pre_last_letter'] == 'y'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['last_letter'] == 'n') & (dataframe_3['pre_last_letter'] == 'e') & (dataframe_3['third_last_letter'] == 'e'), 'Male' ] = 0

dataframe_3.loc[(dataframe_3['first_name'] == 'Kerstin'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['first_name'] == 'Susan'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['first_name'] == 'Ingeborg'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['first_name'] == 'Gernot'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['first_name'] == 'Ümit'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['first_name'] == 'Almut'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['first_name'] == 'Gudrun'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['first_name'] == 'Uwe'), 'Male' ] = 1
dataframe_3.loc[(dataframe_3['first_name'] == 'Ole'), 'Male' ] = 1

dataframe_3.loc[(dataframe_3['last_letter'] == 'i'), 'Male' ] = 0
dataframe_3.loc[(dataframe_3['first_name'] == 'Willi') & (dataframe_3['first_name'] == 'Giovanni') & (dataframe_3['first_name'] == 'Ari') & (dataframe_3['first_name'] == 'Ali')
                & (dataframe_3['first_name'] == 'Kai'), 'Male' ] = 1

#dataframe_3.to_excel(r'C:\\Users\\mariu\\Documents\\Project Local Elections\\bayern_historisch_names.xlsx')
dataframe_3.head(50)

# %%
dataframe_4 = pd.read_excel(r'C:\Users\mariu\Documents\Project Local Elections\bayern_historisch_names.xlsx')
dataframe_4 = dataframe_3.drop(['Unnamed: 0', 'last_letter', 'pre_last_letter', 'third_last_letter', 'fourth_last_letter', 'fifth_last_letter', 'sixth_last_letter',
                 'seventh_last_letter', 'eigth_last_letter'], axis = 1)
dataframe_4.head()

# %%
dataframe_4['prof'] = dataframe_4['name_official'].str.contains('Prof.', regex=False)
dataframe_4['prof'] = dataframe_4['prof'].replace({True:1,False:0})
dataframe_4.last_name = dataframe_4.last_name.str.replace('Prof.', '')
dataframe_4['royal'] = dataframe_4['name_official'].str.contains('von', regex=False)
dataframe_4['royal'] = dataframe_4['royal'].replace({True:1,False:0})
print(dataframe_4.describe())

# %%
dataframe_5 = dataframe_4
dataframe_5['muslim'] = 0
dataframe_5.loc[(dataframe_5['first_name'] == 'Ali') | (dataframe_5['first_name'] == 'Hüseyin') | 
                (dataframe_5['first_name'] == 'Cumali') | (dataframe_5['first_name'] == 'Nükhet') | 
                (dataframe_5['first_name'] == 'Gökhan')
                | (dataframe_5['first_name'] == 'Serafettin') | (dataframe_5['first_name'] == 'Zeynep')
                | (dataframe_5['first_name'] == 'Aysel') | (dataframe_5['first_name'] == 'Gönül') 
                | (dataframe_5['first_name'] == 'Ayten') | (dataframe_5['first_name'] == 'Gülseren') 
                | (dataframe_5['first_name'] == 'Ilknur') | (dataframe_5['first_name'] == 'Kenan')
                | (dataframe_5['first_name'] == 'Cetin') | (dataframe_5['first_name'] == 'Kerem')
                | (dataframe_5['first_name'] == 'Oguz') | (dataframe_5['first_name'] == 'Ilhan')
                | (dataframe_5['first_name'] == 'Asya') | (dataframe_5['first_name'] == 'Tuncay')
                | (dataframe_5['first_name'] == 'Hakan') | (dataframe_5['first_name'] == 'Bülent')
                | (dataframe_5['first_name'] == 'Cem') | (dataframe_5['first_name'] == 'Yasar')
                | (dataframe_5['first_name'] == 'Ilknur') | (dataframe_5['first_name'] == 'Orhan')
                | (dataframe_5['first_name'] == 'Resat') | (dataframe_5['first_name'] == 'Magdi')
                | (dataframe_5['first_name'] == 'Teslime') | (dataframe_5['first_name'] == 'Uygur')
                | (dataframe_5['first_name'] == 'Sedef') | (dataframe_5['first_name'] == 'Ahmet')
                | (dataframe_5['first_name'] == 'Mercan') | (dataframe_5['first_name'] == 'Aziz')
                | (dataframe_5['first_name'] == 'Ismail') | (dataframe_5['first_name'] == 'Ümit')
                | (dataframe_5['first_name'] == 'Yasemin') | (dataframe_5['first_name'] == 'Aynur')
                | (dataframe_5['first_name'] == 'Abdurrahman') | (dataframe_5['first_name'] == 'Süleyman')
                | (dataframe_5['first_name'] == 'Mustafa') | (dataframe_5['first_name'] == 'Senem')
                | (dataframe_5['first_name'] == 'Özlem') | (dataframe_5['first_name'] == 'Taylan')
                | (dataframe_5['first_name'] == 'Zeki') | (dataframe_5['first_name'] == 'Nazile')
                | (dataframe_5['first_name'] == 'Ümran') | (dataframe_5['first_name'] == 'Ferhat')
                | (dataframe_5['first_name'] == 'Neslihan') | (dataframe_5['first_name'] == 'Maksude')
                | (dataframe_5['first_name'] == 'Fadime') | (dataframe_5['first_name'] == 'Güray')
                | (dataframe_5['first_name'] == 'Metin') | (dataframe_5['first_name'] == 'Ramazan')
                | (dataframe_5['first_name'] == 'Bediye') | (dataframe_5['first_name'] == 'Hasim')
                | (dataframe_5['first_name'] == 'Bekir') | (dataframe_5['first_name'] == 'Osman')
                | (dataframe_5['first_name'] == 'Gülten') | (dataframe_5['first_name'] == 'Refiye')
                | (dataframe_5['first_name'] == 'Hatun') | (dataframe_5['first_name'] == 'Arif')
                | (dataframe_5['first_name'] == 'Hassan') | (dataframe_5['first_name'] == 'Celal')
                | (dataframe_5['first_name'] == 'Ibrahim') | (dataframe_5['first_name'] == 'Sevim')
                | (dataframe_5['first_name'] == 'Sait') | (dataframe_5['first_name'] == 'Yetvart')
                | (dataframe_5['first_name'] == 'Ugur') | (dataframe_5['first_name'] == 'Mehmet')
                | (dataframe_5['first_name'] == 'Cemal') | (dataframe_5['first_name'] == 'Tülay')
                | (dataframe_5['first_name'] == 'Muhammet') | (dataframe_5['first_name'] == 'Ayaz')
                | (dataframe_5['first_name'] == 'Mahbubur') | (dataframe_5['first_name'] == 'Durdu')
                | (dataframe_5['first_name'] == 'Tugay') | (dataframe_5['first_name'] == 'Cengiz')
                | (dataframe_5['first_name'] == 'Ekrem') | (dataframe_5['first_name'] == 'Zehra')
                | (dataframe_5['first_name'] == 'Hüsamettin') | (dataframe_5['first_name'] == 'Müslüm')
                | (dataframe_5['first_name'] == 'Kevser') | (dataframe_5['first_name'] == 'Baki')
                | (dataframe_5['first_name'] == 'Ikbal') | (dataframe_5['first_name'] == 'Nejdet')
                | (dataframe_5['first_name'] == 'Güllü') | (dataframe_5['first_name'] == 'Fikret')
                | (dataframe_5['first_name'] == 'Handan') | (dataframe_5['first_name'] == 'Tezcan')
                | (dataframe_5['first_name'] == 'Gülhan') | (dataframe_5['first_name'] == 'Özel')
                | (dataframe_5['first_name'] == 'Hemdegül') | (dataframe_5['first_name'] == 'Nail')
                | (dataframe_5['first_name'] == 'Babür') | (dataframe_5['first_name'] == 'Deniz')
                | (dataframe_5['first_name'] == 'Songül') | (dataframe_5['first_name'] == 'Nebil')
                | (dataframe_5['first_name'] == 'Alper') | (dataframe_5['first_name'] == 'Gülay')
                | (dataframe_5['first_name'] == 'Dilan') | (dataframe_5['first_name'] == 'Nebil')
                | (dataframe_5['first_name'] == 'Birgül') | (dataframe_5['first_name'] == 'Melihat')
                | (dataframe_5['first_name'] == 'Devrim') | (dataframe_5['first_name'] == 'Arzu')
                | (dataframe_5['first_name'] == 'Erkan') | (dataframe_5['first_name'] == 'Nesrin')
                | (dataframe_5['first_name'] == 'Ercan') | (dataframe_5['first_name'] == 'Abdulmesih')
                | (dataframe_5['first_name'] == 'Ayhan') | (dataframe_5['first_name'] == 'Aydin')
                | (dataframe_5['first_name'] == 'Kamran') | (dataframe_5['first_name'] == 'Munib')
                | (dataframe_5['first_name'] == 'Hamed') | (dataframe_5['first_name'] == 'Çigdem')
                | (dataframe_5['first_name'] == 'Hülya') | (dataframe_5['first_name'] == 'Zeynel')
                | (dataframe_5['first_name'] == 'Zafer') | (dataframe_5['first_name'] == 'Dalal')
                | (dataframe_5['first_name'] == 'Cafer') | (dataframe_5['first_name'] == 'Yasin')
                | (dataframe_5['first_name'] == 'Batoul') | (dataframe_5['first_name'] == 'Murat')
                | (dataframe_5['first_name'] == 'Halil') | (dataframe_5['first_name'] == 'Gülcin')
                | (dataframe_5['first_name'] == 'Zafar') | (dataframe_5['first_name'] == 'Sanjar')
                | (dataframe_5['first_name'] == 'Tugba') | (dataframe_5['first_name'] == 'Raziye')
                | (dataframe_5['first_name'] == 'Aliye') | (dataframe_5['first_name'] == 'Niyazi')
                | (dataframe_5['first_name'] == 'Kemal') | (dataframe_5['first_name'] == 'Özgür')
                | (dataframe_5['first_name'] == 'Veysel') | (dataframe_5['first_name'] == 'Khaled')
                | (dataframe_5['first_name'] == 'Idris') | (dataframe_5['first_name'] == 'Yilmaz')
                | (dataframe_5['first_name'] == 'Önder') | (dataframe_5['first_name'] == 'Tülin')
                | (dataframe_5['first_name'] == 'Göktürk') | (dataframe_5['first_name'] == 'Sadik')
                | (dataframe_5['first_name'] == 'Selvet') | (dataframe_5['first_name'] == 'Abdellatif')
                | (dataframe_5['first_name'] == 'Hava') | (dataframe_5['first_name'] == 'Sengül')
                | (dataframe_5['first_name'] == 'Erhan') | (dataframe_5['first_name'] == 'Ergün')
                | (dataframe_5['first_name'] == 'Serdar') | (dataframe_5['first_name'] == 'Yunus')
                | (dataframe_5['first_name'] == 'Nurullah') | (dataframe_5['first_name'] == 'Nida')
                | (dataframe_5['first_name'] == 'Nursan') | (dataframe_5['first_name'] == 'Berkkan')
                | (dataframe_5['first_name'] == 'Ertürk') | (dataframe_5['first_name'] == 'Sakine')
                | (dataframe_5['first_name'] == 'Ufuk') | (dataframe_5['first_name'] == 'Kasim')
                | (dataframe_5['first_name'] == 'Lütfi') | (dataframe_5['first_name'] == 'Emrah')
                | (dataframe_5['first_name'] == 'Gürsoy') | (dataframe_5['first_name'] == 'Yusuf')
                | (dataframe_5['first_name'] == 'Maryam') | (dataframe_5['first_name'] == 'Rabiye')
                | (dataframe_5['first_name'] == 'Gülbeyaz') | (dataframe_5['first_name'] == 'Nezaket')
                | (dataframe_5['first_name'] == 'Riza') | (dataframe_5['first_name'] == 'Görkan')
                | (dataframe_5['first_name'] == 'Mohamad') | (dataframe_5['first_name'] == 'Mohammad')
                | (dataframe_5['first_name'] == 'Yavuz') | (dataframe_5['first_name'] == 'Hachem')
                | (dataframe_5['first_name'] == 'Kaan') | (dataframe_5['first_name'] == 'Erdal')
                , 'muslim' ] = 1

dataframe_5.head(50)

# %%
dataframe_5['votes'] = dataframe_5['votes'].apply(int)
dataframe_5['place_list'] = dataframe_5['place_list'].apply(int)

#dataframe_5.to_excel(r'C:\\Users\\mariu\\Documents\\Project Local Elections\\bayern_historisch_names.xlsx')

print(dataframe_5.describe())

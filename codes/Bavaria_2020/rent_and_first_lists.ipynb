# %%
import pandas as pd

# %%
dataframe = pd.read_excel(r'C:\Users\mariu\Documents\Project Local Elections\bayern_historisch.xlsx')

# %%
# Code values from Website 
# For later: Automate Data Mining with Web scraping
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2014), 'cost_o_liv'] = 14.49
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2008), 'cost_o_liv'] = 11.95
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2002), 'cost_o_liv'] = 8.86
dataframe.loc[(dataframe['city'] == 'Nürnberg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.97
dataframe.loc[(dataframe['city'] == 'Nürnberg') & (dataframe['year'] == 2008), 'cost_o_liv'] = 7.03
dataframe.loc[(dataframe['city'] == 'Augsburg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.04
dataframe.loc[(dataframe['city'] == 'Augsburg') & (dataframe['year'] == 2008), 'cost_o_liv'] = 6.55
dataframe.loc[(dataframe['city'] == 'Ingolstadt') & (dataframe['year'] == 2014), 'cost_o_liv'] = 9.92
dataframe.loc[(dataframe['city'] == 'Würzburg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.97
dataframe.loc[(dataframe['city'] == 'Fürth') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.43
dataframe.loc[(dataframe['city'] == 'Erlangen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 9.83
dataframe.loc[(dataframe['city'] == 'Erlangen') & (dataframe['year'] == 2008), 'cost_o_liv'] = 7.35
dataframe.loc[(dataframe['city'] == 'Bamberg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.04
dataframe.loc[(dataframe['city'] == 'Bamberg') & (dataframe['year'] == 2008), 'cost_o_liv'] = 6.55
dataframe.loc[(dataframe['city'] == 'Bayreuth') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.76
dataframe.loc[(dataframe['city'] == 'Bayreuth') & (dataframe['year'] == 2008), 'cost_o_liv'] = 5.71
dataframe.loc[(dataframe['city'] == 'Landshut') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.91
dataframe.loc[(dataframe['city'] == 'Landshut') & (dataframe['year'] == 2008), 'cost_o_liv'] = 6.79
dataframe.loc[(dataframe['city'] == 'Aschaffenburg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.90
dataframe.loc[(dataframe['city'] == 'Neu Ulm') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.30
dataframe.loc[(dataframe['city'] == 'Passau') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.31
dataframe.loc[(dataframe['city'] == 'Passau') & (dataframe['year'] == 2008), 'cost_o_liv'] = 5.47
dataframe.loc[(dataframe['city'] == 'Straubing') & (dataframe['year'] == 2014), 'cost_o_liv'] = 5.66
dataframe.loc[(dataframe['city'] == 'Straubing') & (dataframe['year'] == 2008), 'cost_o_liv'] = 7.41
dataframe.loc[(dataframe['city'] == 'Dachau') & (dataframe['year'] == 2014), 'cost_o_liv'] = 10.74
dataframe.loc[(dataframe['city'] == 'Dachau') & (dataframe['year'] == 2008), 'cost_o_liv'] = 10.26
dataframe.loc[(dataframe['city'] == 'Kaufbeuren') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.02
dataframe.loc[(dataframe['city'] == 'Ansbach') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.76
dataframe.loc[(dataframe['city'] == 'Ansbach') & (dataframe['year'] == 2008), 'cost_o_liv'] = 4.83
dataframe.loc[(dataframe['city'] == 'Coburg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.22
dataframe.loc[(dataframe['city'] == 'Coburg') & (dataframe['year'] == 2008), 'cost_o_liv'] = 5.15
dataframe.loc[(dataframe['city'] == 'Germering') & (dataframe['year'] == 2014), 'cost_o_liv'] = 10.90
dataframe.loc[(dataframe['city'] == 'Fürstenfeldbruck') & (dataframe['year'] == 2014), 'cost_o_liv'] = 10.24
dataframe.loc[(dataframe['city'] == 'Fürstenfeldbruck') & (dataframe['year'] == 2008), 'cost_o_liv'] = 9.29
dataframe.loc[(dataframe['city'] == 'Friedberg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.25
dataframe.loc[(dataframe['city'] == 'Deggendorf') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.13
dataframe.loc[(dataframe['city'] == 'Deggendorf') & (dataframe['year'] == 2008), 'cost_o_liv'] = 6.35
dataframe.loc[(dataframe['city'] == 'Unterschleißheim') & (dataframe['year'] == 2014), 'cost_o_liv'] = 11.46
dataframe.loc[(dataframe['city'] == 'Olching') & (dataframe['year'] == 2014), 'cost_o_liv'] = 10.88
dataframe.loc[(dataframe['city'] == 'Lauf a.d. Pegnitz') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.37
dataframe.loc[(dataframe['city'] == 'Pfaffenhofen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.30
dataframe.loc[(dataframe['city'] == 'Pfaffenhofen') & (dataframe['year'] == 2008), 'cost_o_liv'] = 7.01
dataframe.loc[(dataframe['city'] == 'Kulmbach') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.0
dataframe.loc[(dataframe['city'] == 'Neusäß') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.43
dataframe.loc[(dataframe['city'] == 'Neusäß') & (dataframe['year'] == 2008), 'cost_o_liv'] = 6.92
dataframe.loc[(dataframe['city'] == 'Kitzingen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.22
dataframe.loc[(dataframe['city'] == 'Karlsfeld') & (dataframe['year'] == 2014), 'cost_o_liv'] = 12.63
dataframe.loc[(dataframe['city'] == 'Lichtenfels') & (dataframe['year'] == 2014), 'cost_o_liv'] = 4.21
dataframe.loc[(dataframe['city'] == 'Bad Aibling') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.89
dataframe.loc[(dataframe['city'] == 'Burghausen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.55
dataframe.loc[(dataframe['city'] == 'Taufkirchen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 12.44
dataframe.loc[(dataframe['city'] == 'Illertissen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.14
dataframe.loc[(dataframe['city'] == 'Kronach') & (dataframe['year'] == 2014), 'cost_o_liv'] = 4.71
dataframe.loc[(dataframe['city'] == 'Kronach') & (dataframe['year'] == 2008), 'cost_o_liv'] = 3.93
dataframe.loc[(dataframe['city'] == 'Kehlheim') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.78
dataframe.loc[(dataframe['city'] == 'Vilshofen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 5.16
dataframe.loc[(dataframe['city'] == 'Gunzenhausen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 5.00
dataframe.loc[(dataframe['city'] == 'Penzberg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.67
dataframe.loc[(dataframe['city'] == 'Regenstauf') & (dataframe['year'] == 2014), 'cost_o_liv'] = 5.89
dataframe.loc[(dataframe['city'] == 'Pocking') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.31
dataframe.loc[(dataframe['city'] == 'Pocking') & (dataframe['year'] == 2008), 'cost_o_liv'] = 5.22
dataframe.loc[(dataframe['city'] == 'Bad Wörishofen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.25
dataframe.loc[(dataframe['city'] == 'Wendelstein') & (dataframe['year'] == 2014), 'cost_o_liv'] = 5.22
dataframe.loc[(dataframe['city'] == 'Bad Neustadt') & (dataframe['year'] == 2014), 'cost_o_liv'] = 4.52
dataframe.loc[(dataframe['city'] == 'Neustadt b. Coburg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 4.06
dataframe.loc[(dataframe['city'] == 'Mainburg') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.28
dataframe.loc[(dataframe['city'] == 'Selb') & (dataframe['year'] == 2014), 'cost_o_liv'] = 4.32
dataframe.loc[(dataframe['city'] == 'Selb') & (dataframe['year'] == 2008), 'cost_o_liv'] = 4.02
dataframe.loc[(dataframe['city'] == 'Stadtbergen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 8.56
dataframe.loc[(dataframe['city'] == 'Dorfen') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.62
dataframe.loc[(dataframe['city'] == 'Maisach') & (dataframe['year'] == 2014), 'cost_o_liv'] = 9.71
dataframe.loc[(dataframe['city'] == 'Eching') & (dataframe['year'] == 2014), 'cost_o_liv'] = 10.65
dataframe.loc[(dataframe['city'] == 'Grafing') & (dataframe['year'] == 2014), 'cost_o_liv'] = 9.52
dataframe.loc[(dataframe['city'] == 'Feucht') & (dataframe['year'] == 2014), 'cost_o_liv'] = 6.50
dataframe.loc[(dataframe['city'] == 'Haßfurt') & (dataframe['year'] == 2014), 'cost_o_liv'] = 5.78
dataframe.loc[(dataframe['city'] == 'Markt Schwaben') & (dataframe['year'] == 2014), 'cost_o_liv'] = 9.75
dataframe.loc[(dataframe['city'] == 'Krumbach') & (dataframe['year'] == 2014), 'cost_o_liv'] = 7.49
dataframe.loc[(dataframe['city'] == 'Pegnitz') & (dataframe['year'] == 2014), 'cost_o_liv'] = 4.93

# %%
list_parties_2014 = []
list_years = dataframe.year.unique()
list_cities = dataframe.city.unique()

for i in list_cities:
    
    dataframe_2 = dataframe[dataframe['city'] == i]
    
    for j in list_years:
        
        dataframe_3 = dataframe_2[dataframe_2['year'] == j]
        
        list_parties_2014.append(dataframe_3.party.unique())

list_parties_2014 # List of all parties for each city and each year

# I don't know how to get a structure into this
# Issues to solve: - One, Two or Three periods of time for cities -> no regular pattern
# Do not compare across different cities -> For now, solve manually
# Out:
# [array(['CSU', 'SPD', 'FW', 'Grüne', 'FDP', 'Linke', 'RoLi', 'ödp', 'BP',
#         'BIA', 'AfD', 'Die Freiheit', 'Piraten', 'HUT'], dtype=object),
#  array(['CSU', 'SPD', 'Grüne', 'FDP', 'RoLi', 'Linke', 'ödp', 'BP', 'ProM',
#         'BIA', 'FW'], dtype=object),
#  array(['CSU', 'SPD', 'Grüne', 'FDP', 'REP', 'DaCG', 'RoLi', 'ASP', 'ödp',
#         'FW', 'Linke'], dtype=object),
#  array(['CSU', 'SPD', 'FW', 'Grüne', 'Linke', 'BIA', 'FDP', 'Die Guten',
#         'ödp', 'Piraten'], dtype=object),
#  array(['CSU', 'SPD', 'Grüne', 'BIA', 'REP', 'FDP', 'Die Guten', 'FW',
#         'Linke', 'ödp'], dtype=object),
#  array(['CSU', 'SPD', 'Grüne', 'REP', 'FW', 'FDP', 'Die Guten', 'BIA',
#         'BIL', 'Linke'], dtype=object),
#  array(['CSU', 'SPD', 'FW', 'Grüne', 'Pro Augsburg', 'Linke', 'AfD', 'CSM',
#         'FDP', 'ödp', 'Polit-WG'], dtype=object),
#  array(['CSU', 'SPD', 'Grüne', 'FB', 'FW', 'ödp', 'Linke', 'FDP',
#         'Pro Augsburg'], dtype=object),
# ...

# %%
# Identify the lists that stand for the first time
# -> with this we can identify entrants that attract more attention than a comparable list 
# (Every supply creates it's demand)

dataframe['first_try'] = 0
# München
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Die Freiheit'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'HUT'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'AfD'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Piraten'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'BP'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'ProM'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'BIA'), 'first_try'] = 1

# Not possible to retrieve from data -> Research
dataframe.loc[(dataframe['city'] == 'München') & (dataframe['year'] == 2002)
              & (dataframe['party'] == 'Linke'), 'first_try'] = 1


# Nürnberg
dataframe.loc[(dataframe['city'] == 'Nürnberg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Piraten'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Nürnberg') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Linke'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Nürnberg') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'ödp'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Nürnberg') & (dataframe['year'] == 2002)
              & (dataframe['party'] == 'BIA'), 'first_try'] = 1


# Augsburg
dataframe.loc[(dataframe['city'] == 'Augsburg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'AfD'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Augsburg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'CSM'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Augsburg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Polit-WG'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Augsburg') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Pro Augsburg'), 'first_try'] = 1


# Ingolstadt
dataframe.loc[(dataframe['city'] == 'Ingolstadt') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'BGI'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Ingolstadt') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'LINKE'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Ingolstadt') & (dataframe['year'] == 2002)
              & (dataframe['party'] == 'FW'), 'first_try'] = 1

# Würzburg
dataframe.loc[(dataframe['city'] == 'Würzburg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'ZfW'), 'first_try'] = 1


# Erlangen
dataframe.loc[(dataframe['city'] == 'Erlangen') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Linke'), 'first_try'] = 1


# Bamberg
dataframe.loc[(dataframe['city'] == 'Bamberg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Bambergs Unabhängige Bürger'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Bamberg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Linke'), 'first_try'] = 1


# Bayreuth
dataframe.loc[(dataframe['city'] == 'Bayreuth') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Die Unabhängigen'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Bayreuth') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'BT go! Junge Liste Bayreuth'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Bayreuth') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Bayreuther Bürger-Liste'), 'first_try'] = 1


# Landshut
dataframe.loc[(dataframe['city'] == 'Landshut') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Landshuter Mitte'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Landshut') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Junge Liste Landshut'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Landshut') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Bayernpartei'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Landshut') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Bürger für Landshut'), 'first_try'] = 1


# Aschaffenburg
dataframe.loc[(dataframe['city'] == 'Aschaffenburg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'ödp'), 'first_try'] = 1


# Passau
dataframe.loc[(dataframe['city'] == 'Passau') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Pro Passau'), 'first_try'] = 1


# Straubing
dataframe.loc[(dataframe['city'] == 'Straubing') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'FDP'), 'first_try'] = 1


# Dachau
dataframe.loc[(dataframe['city'] == 'Dachau') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Bürger für Dach'), 'first_try'] = 1


# Coburg
dataframe.loc[(dataframe['city'] == 'Coburg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Linke'), 'first_try'] = 1

dataframe.loc[(dataframe['city'] == 'Straubing') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'CSB'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Straubing') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Junges Coburg'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Straubing') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Bürger bewegen Coburg'), 'first_try'] = 1


# Fürstenfeldbruck
dataframe.loc[(dataframe['city'] == 'Fürstenfeldbruck') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'ödp'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Fürstenfeldbruck') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Piraten'), 'first_try'] = 1

# Deggendorf
dataframe.loc[(dataframe['city'] == 'Deggendorf') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'FDP'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Deggendorf') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'Junge Liste'), 'first_try'] = 1


# Friedberg
dataframe.loc[(dataframe['city'] == 'Friedberg') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'ödp'), 'first_try'] = 1


# Olching
dataframe.loc[(dataframe['city'] == 'Olching') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'FDP'), 'first_try'] = 1


# Kitzingen
dataframe.loc[(dataframe['city'] == 'Kitzingen') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'BP'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Kitzingen') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'ProKT'), 'first_try'] = 1


# Karlsfeld
dataframe.loc[(dataframe['city'] == 'Karlsfeld') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'FW'), 'first_try'] = 1


# Bad Aibling
dataframe.loc[(dataframe['city'] == 'Bad Aibling') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'ödp'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Bad Aibling') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'BP'), 'first_try'] = 1


# Taufenkirchen
dataframe.loc[(dataframe['city'] == 'Taufenkirchen') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'FDP'), 'first_try'] = 1


# Kronach
dataframe.loc[(dataframe['city'] == 'Kronach') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Grüne'), 'first_try'] = 1


# Pocking
dataframe.loc[(dataframe['city'] == 'Pocking') & (dataframe['year'] == 2008)
              & (dataframe['party'] == 'FDP'), 'first_try'] = 1


# Wendelstein
dataframe.loc[(dataframe['city'] == 'Wendelstein') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Grüne'), 'first_try'] = 1


# Eching
dataframe.loc[(dataframe['city'] == 'Eching') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Grüne'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Eching') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Echinger Mitte'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Eching') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Bürger für Eching'), 'first_try'] = 1


# Feucht
dataframe.loc[(dataframe['city'] == 'Feucht') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Die Franken'), 'first_try'] = 1


# Markt Schwaben
dataframe.loc[(dataframe['city'] == 'Markt Schwaben') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'FDP'), 'first_try'] = 1


# Pegnitz
dataframe.loc[(dataframe['city'] == 'Pegnitz') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'PEG'), 'first_try'] = 1
dataframe.loc[(dataframe['city'] == 'Pegnitz') & (dataframe['year'] == 2014)
              & (dataframe['party'] == 'Zukunft Pegnitz'), 'first_try'] = 1

# %%
dataframe.to_excel(r'C:\Users\mariu\Documents\Project Local Elections\bayern_historisch.xlsx')

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

# %%
# load overview over municipalities
df = pd.read_excel("../data/NRW/nrw_mun.xlsx")

# select rows and columns
muns = df.loc[df['Wer']=='Edith', ['Gemeinde', 'Gemeindeschlüssel']]
muns.columns = ['mun_name', 'mun_code']

# %%
def get_url1(name):
    e.send_keys(name)
    e.send_keys(Keys.ENTER)
    soup = BeautifulSoup(d.page_source)
    d.find_element_by_id('suchfeld').clear()
    time.sleep(0.7)
    links = soup.find('tbody').find_all('a') 
    return [link.get('href') for link in links if 'Votemanager' not in link]

# %%
# set up webdriver and search field element
d=webdriver.Chrome("../chromedriver.exe")
d.get('https://wahlen.votemanager.de/#')
e = d.find_element_by_id('suchfeld')

# search for each municipality and get the url to the municipality specific overview page
muns['url'] = muns['mun_name'].apply(get_url1)

# %%
# now, direct to the elections on 25-05-2014

# %%
# Select Ratswahl from all the elections happened that day

# %%
# Define function to get the Ratswahl-specific urls for each municipality
def get_ratswahlurl(overview_url):
    """ To get the urls specific to the Ratswahl elections.
    It takes as input the overview url for each municipality from wahlen.regioit
    and returns a list of all Ratswahl-url from its html text.
    """
    r = requests.get(overview_url)
    soup = BeautifulSoup(r.text)
    return [link.get('href') for link in soup.find_all('a') if 'Ratswahl' in link]

# %%
# Apply function to url column of municipality dataframe
muns['ratswahl_url'] = muns['url'].apply(get_ratswahlurl)

# %%
# get all the Wahlbezirke

# %%
# for each Wahlbezirk get the results table

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(muns)
# Out:
#                   mun_name  mun_code  \
# 1                 Duisburg   5112000
# 5      Mülheim an der Ruhr   5117000
# 9                Wuppertal   5124000
# 13                    Goch   5154016
# 17                Kevelaer   5154032
# 21                 Rheurdt   5154048
# 25                   Weeze   5154064
# 29                  Hilden   5158016
# 33                Ratingen   5158028
# 37            Grevenbroich   5162008
# 41               Meerbusch   5162022
# 45                Grefrath   5166008
# 49              Schwalmtal   5166024
# 53                   Alpen   5170004
# 57           Kamp-Lintfort   5170020
# 61              Schermbeck   5170036
# 65                  Xanten   5170052
# 69                  Aachen   5334002
# 73            Herzogenrath   5334016
# 77        Stolberg (Rhld.)   5334032
# 81                Heimbach   5358012
# 85                 Kreuzau   5358028
# 89                Nideggen   5358044
# 93                Vettweiß   5358060
# 97                 Elsdorf   5362016
# 101                 Kerpen   5362032
# 105            Blankenheim   5366008
# 109                   Kall   5366024
# 113            Weilerswist   5366040
# 117          Geilenkirchen   5370012
# 121        Übach-Palenberg   5370028
# 125           Bergneustadt   5374004
# 129                Lindlar   5374020
# 133           Radevormwald   5374036
# 137            Wipperfürth   5374052
# 141    Leichlingen (Rhld.)   5378016
# 145         Wermelskirchen   5378032
# 149                 Eitorf   5382016
# 153             Meckenheim   5382032
# 157              Rheinbach   5382048
# 161               Swisttal   5382064
# 165                Bottrop   5512000
# 169                Bocholt   5554008
# 173                   Heek   5554024
# 177               Raesfeld   5554040
# 181              Stadtlohn   5554056
# 185              Ascheberg   5558004
# 189              Havixbeck   5558020
# 193                  Olfen   5558036
# 197                Datteln   5562008
# 201                 Herten   5562020
# 205                Waltrop   5562036
# 209                Hörstel   5566016
# 213              Ladbergen   5566032
# 217                  Lotte   5566048
# 221              Nordwalde   5566064
# 225               Saerbeck   5566080
# 229             Wettringen   5566096
# 233          Drensteinfurt   5570016
# 237              Ostbevern   5570032
# 241              Wadersloh   5570048
# 245              Gütersloh   5754008
# 249             Langenberg   5754024
# 253             Steinhagen   5754040
# 257                  Bünde   5758004
# 261           Kirchlengern   5758020
# 265                 Vlotho   5758036
# 269                 Brakel   5762016
# 273              Steinheim   5762032
# 277          Bad Salzuflen   5766008
# 281              Dörentrup   5766024
# 285                   Lage   5766040
# 289          Oerlinghausen   5766056
# 293              Espelkamp   5770008
# 297                 Minden   5770024
# 301                 Rahden   5770040
# 305                Borchen   5774012
# 309              Lichtenau   5774028
# 313                 Bochum   5911000
# 317                  Herne   5916000
# 321              Hattingen   5954016
# 325          Wetter (Ruhr)   5954032
# 329                 Brilon   5958012
# 333               Medebach   5958028
# 337    Sundern (Sauerland)   5958044
# 341                 Halver   5962012
# 345                Kierspe   5962028
# 349  Nachrodt-Wiblingwerde   5962044
# 353                Werdohl   5962060
# 357            Kirchhundem   5966016
# 361          Bad Berleburg   5970004
# 365            Hilchenbach   5970020
# 369            Neunkirchen   5970036
# 373         Bad Sassendorf   5974008
# 377               Lippetal   5974024
# 381                  Soest   5974040
# 385         Wickede (Ruhr)   5974056
# 389            Holzwickede   5978016
# 393                   Selm   5978032
#
#                                                    url
# 1    [http://wahlergebnis.duisburg.de/05112000/inde...
# 5    [https://wahlpraesentation.muelheim-ruhr.de/05...
# 9    [https://wahlen.wuppertal.de/05124000/index.html]
# 13                   [https://vote-it.de/?page_id=146]
# 17                   [https://vote-it.de/?page_id=146]
# 21                   [https://vote-it.de/?page_id=146]
# 25                   [https://vote-it.de/?page_id=146]
# 29   [https://wahlen.regioit.de/3/05158016/index.html]
# 33   [https://wahlen.regioit.de/3/05158028/index.html]
# 37   [http://wep.itk-rheinland.de/vm/prod/05162008/...
# 41   [http://wep.itk-rheinland.de/vm/prod/05162022/...
# 45                   [https://vote-it.de/?page_id=146]
# 49   [https://votemanager-gi.ekom21cdn.de/06535017/...
# 53                   [https://vote-it.de/?page_id=146]
# 57                   [https://vote-it.de/?page_id=146]
# 61                   [https://vote-it.de/?page_id=146]
# 65                   [https://vote-it.de/?page_id=146]
# 69   [https://wahlen.regioit.de/1/05334002/index.ht...
# 73   [https://wahlen.regioit.de/1/05334016/index.html]
# 77   [https://wahlen.regioit.de/1/05334032/index.html]
# 81   [https://wahlen.kdvz-frechen.de/kdvz/05358012/...
# 85   [https://wahlen.kdvz-frechen.de/kdvz/05358028/...
# 89   [https://wahlen.kdvz-frechen.de/kdvz/05358044/...
# 93   [https://wahlen.kdvz-frechen.de/kdvz/05358060/...
# 97   [https://okvote.osrz-akdb.de/OK.VOTE_MF/095721...
# 101  [https://wahlen.kdvz-frechen.de/kdvz/05362032/...
# 105  [https://wahlen.regioit.de/2/05366008/index.html]
# 109  [https://wahlen.kdvz-frechen.de/kdvz/05366024/...
# 113  [https://wahlen.kdvz-frechen.de/kdvz/05366040/...
# 117  [https://stadt-gk.de/wahlen/Ergebnisse/EUW2019...
# 121          [https://wahl.krz.de/05370028/index.html]
# 125  [https://wahlen.kdvz-frechen.de/civitec/053740...
# 129  [https://wahlen.kdvz-frechen.de/civitec/053740...
# 133  [https://wahlen.kdvz-frechen.de/civitec/053740...
# 137  [https://wahlen.kdvz-frechen.de/civitec/053740...
# 141     [http://wahlen.citkomm.de/05378016/index.html]
# 145     [http://wahlen.citkomm.de/05378032/index.html]
# 149  [https://wahlen.kdvz-frechen.de/civitec/053820...
# 153  [https://wahlen.kdvz-frechen.de/civitec/053820...
